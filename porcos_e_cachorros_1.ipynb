# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavokuhl/CRUD-PHP-7.4/blob/main/porcos_e_cachorros_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# features (1 sim, 0 não)
# pelo longo?
# pena curta?
# faz auau?
porco1 = [0, 1, 0]
porco2 = [0, 1, 1]
porco3 = [1, 1, 0]

cachorro1 = [0, 1, 1]
cachorro2 = [1, 0, 1]
cachorro3 = [1, 1, 1]

# material de análise
dados = [porco1, porco2, porco3, cachorro1, cachorro2, cachorro3]

# classe => valor correto do dado
# 1 => porco, 0 => cachorro
classes = [1, 1, 1, 0, 0, 0]

# %%
# estimador básico
from sklearn.svm import LinearSVC

model = LinearSVC()
model.fit(dados, classes)
# Out:
# LinearSVC()

# %%
# adivinhe se o animal é um 1 => porco ou 0 => cachorro 
animal_misterioso = [1, 1, 1]
# resultado da análise
model.predict([animal_misterioso])
# Out:
# array([0])

# %%
misterio1 = [1,1,1]
misterio2 = [1,1,0]
misterio3 = [0,1,1]

# material de análise
testes = [misterio1, misterio2, misterio3]
# resultado da análise
previsoes = model.predict(testes)

# valores reais de cada misterio
testes_classes = [0, 1, 1]

# verificar tipo especial numpy.ndarray
type(previsoes)
# Out:
# numpy.ndarray

# %%
# acertos
previsoes == testes_classes
# Out:
# array([ True,  True, False])

# %%
# numpy.ndarray
corretos = (previsoes == testes_classes).sum()

total = len(testes)
taxa_de_acerto = corretos/total
print("Taxa de acerto", taxa_de_acerto * 100)
# Out:
# Taxa de acerto 66.66666666666666

# %%
# accuracy == taxa de acerto
from sklearn.metrics import accuracy_score

taxa_de_acerto = accuracy_score(testes_classes, previsoes)
print("Taxa de acerto", taxa_de_acerto * 100)
# Out:
# Taxa de acerto 66.66666666666666
